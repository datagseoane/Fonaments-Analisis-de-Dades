# %% [markdown]
# ## Tasca S5 T01

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dataset/peticions_ciutadanes.csv")

# %%
df.shape
# Out:
# (21999, 25)

# %% [markdown]
# ### Exercici 1

# %%
xpoints = np.array([0, 7, 14, 21, 28, 35])
ypoints = np.array([1, 2, 3, 4, 5, 6])

# %%
plt.plot(xpoints, ypoints)

plt.show()

# %% [markdown]
# ### Exercici 2

# %%
plt.plot(xpoints, ypoints, marker = "d", markersize = 20)

plt.title("Exercici 1")
plt.xlabel("ciutadans")
plt.ylabel("€")

pl

plt.show()

# %% [markdown]
# ### Exercici 3

# %%
plotdata = df.groupby(['TIPUS']).TIPUS.count()
print(plotdata)
# Out:
# TIPUS
# AGRAIMENT               51
# CONSULTA              6343
# INCIDENCIA           10371
# PETICIO DE SERVEI      581
# QUEIXA                3555
# SUGGERIMENT           1098
# Name: TIPUS, dtype: int64

# %%
plotdata.plot(kind='bar')

plt.title("Gestions per tipus incidencies")
plt.ylabel("Nº incidencies")
plt.xlabel("Tipus incidencicies")

plt.show()

# %% [markdown]
# ## Exercici 4

# %%
plotdata1 = df.groupby(['TIPUS','MES_DATA_TANCAMENT']).size().unstack()
print(plotdata1)
# Out:
# MES_DATA_TANCAMENT     1     2
# TIPUS
# AGRAIMENT             40    11
# CONSULTA            5286  1057
# INCIDENCIA          8257  2114
# PETICIO DE SERVEI    468   113
# QUEIXA              2766   789
# SUGGERIMENT          817   281

# %%
plotdata1.plot(kind='bar')

plt.show()

# %% [markdown]
# ### Exercici 5

# %%
data2 = df.groupby(['ANY_DATA_ALTA','TIPUS']).size().unstack()

# %%
data2.plot(kind='bar', stacked = True)

plt.xlabel("ANY")

plt.show()

# %% [markdown]
# En el gràfic es veu el notable increment de peticions ciutadanes en aquest darrer any
